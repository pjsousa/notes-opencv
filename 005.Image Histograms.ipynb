# %%
import notebook_util
import cv2
from matplotlib import pyplot as plt
import numpy as np
notebook_util.override_imshow(cv2)

# %matplotlib inline

# %%
bgr_sunset = cv2.imread("./resources/sunset.jpg")
bgr_tftscreen = cv2.imread("./resources/pcmasterrace.jpg")
bgr_cat = cv2.imread("./resources/cat.jpg")

# %%
cv2.imshow("Cat", bgr_cat, (9,5))
cv2.imshow("Tft", bgr_tftscreen, (9,5))
# Out:
# Showing Image: Cat
# Showing Image: Tft

# %% [markdown]
# We can have a feel of what the distribution for each channel maybe in our images using histograms.
#
# OpenCV calculates the histogram for each channel using **calcHist**

# %%
image = bgr_cat

# We plot a histogram, ravel() flatens our image array 
plt.hist(image.ravel(), 256, [0, 256]); plt.show()

# Viewing Separate Color Channels
color = ('b', 'g', 'r')

# We now separate the colors and plot each in the Histogram
for i, col in enumerate(color):
    histogram2 = cv2.calcHist([image], [i], None, [256], [0, 256])
    plt.plot(histogram2, color = col)
    plt.xlim([0,256])
    
plt.show()

cv2.imshow("input", image, (9,5))
# Out:
# Showing Image: input
