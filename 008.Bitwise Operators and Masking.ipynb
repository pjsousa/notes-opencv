# %%
import notebook_util
import cv2
from matplotlib import pyplot as plt
import numpy as np
notebook_util.override_imshow(cv2)

# %matplotlib inline

# %%
image_data = cv2.imread("./resources/dogs.jpg")

cv2.imshow("Image", image_data)
# Out:
# Showing Image: Image

# %%
image_data.shape
# Out:
# (428, 640, 3)

# %% [markdown]
# ## Bitwise operations

# %%
#lets initialize two masks with the same size as our image

mask1 = np.zeros(image_data.shape[:2], np.uint8)
mask2 = np.zeros(image_data.shape[:2], np.uint8)

cv2.rectangle(mask1, (90, 120), (380, 380), 255, -2)
cv2.rectangle(mask2, (350, 10), (635, 380), 255, -2)

cv2.imshow("mask1", mask1)
cv2.imshow("mask2", mask2)
# Out:
# Showing Image: mask1
# Showing Image: mask2

# %%
# Shows only where they intersect
And = cv2.bitwise_and(mask1, mask2)
cv2.imshow("AND", And)
# Out:
# Showing Image: AND

# %%
# Shows where either square or ellipse is 
bitwiseOr = cv2.bitwise_or(mask1, mask2)
cv2.imshow("OR", bitwiseOr)
# Out:
# Showing Image: OR

# %%
# Shows where either exist by itself
bitwiseXor = cv2.bitwise_xor(mask1, mask2)
cv2.imshow("XOR", bitwiseXor)
# Out:
# Showing Image: XOR

# %%
# Shows everything that isn't part of the square
bitwiseNot_sq = cv2.bitwise_not(mask1)
cv2.imshow("NOT - square", bitwiseNot_sq)
# Out:
# Showing Image: NOT - square

# %%
bitwiseNot_ell = cv2.bitwise_not(mask2)
cv2.imshow("NOT - ellipse", bitwiseNot_ell)
#cv2.waitKey(0)
# Out:
# Showing Image: NOT - ellipse

# %% [markdown]
# So far we applied masks together with one another. But we can use the same operators to now apply the masks to the image itself

# %%
puppy = cv2.bitwise_and(image_data, image_data, mask = mask1)
cv2.imshow("Only show puppy", puppy)
# Out:
# Showing Image: Only show puppy

# %%
dog = cv2.bitwise_and(image_data, image_data, mask = mask2)
cv2.imshow("Only show big[gish] dog", dog)
# Out:
# Showing Image: Only show big[gish] dog

# %%
dog = cv2.bitwise_and(image_data, image_data, mask = And)
cv2.imshow("Only show the intersection of the two masks", dog)
# Out:
# Showing Image: Only show the intersection of the two masks

# %%
dog = cv2.bitwise_and(image_data, image_data, mask = bitwiseOr)
cv2.imshow("Show the two dogs", dog)
# Out:
# Showing Image: Show the two dogs
