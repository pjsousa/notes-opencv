# %%
import notebook_util

# %%
import cv2

# %%
image_data = cv2.imread("./resources/car2.jpg")

# %%
#cv2.imshow("Car", image_data)

# %%
notebook_util.override_imshow(cv2)

# %%
cv2.imshow("Car", image_data, (10, 7))
# Out:
# Showing Image: Car

# %%
# imread returns simply a numpy array
print("Variable type: {}".format(type(image_data)))
print("Image Size: [{} x {}](W x H)".format(image_data.shape[0], image_data.shape[1]))
# Out:
# Variable type: <type 'numpy.ndarray'>
# Image Size: [2448 x 3264](W x H)
